# %%
import pandas as pd

# %%
# system_csv = "systems.csv"

# %%
system_data = pd.read_csv('systems.csv')
system_data
# Out:
#     Country Code                Name               Location  \
# 0             AE         Careem BIKE              Dubai, AE
# 1             AR             Ecobici       Buenos Aires, AR
# 2             AR        MiBiciTuBici  Rosario, Santa Fe, AR
# 3             AR   Movo Buenos Aires       Buenos Aires, AR
# 4             AT      city bike Linz               Linz, AT
# ..           ...                 ...                    ...
# 556           US      Wheels Orlando            Orlando, FL
# 557           US    Wheels San Diego          San Diego, CA
# 558           US      Wheels Seattle            Seattle, WA
# 559           US  Wheels Tallahassee        Tallahassee, FL
# 560           US        Wheels Tempe              Tempe, AZ
#
#                                 System ID  \
# 0                             careem_bike
# 1                        bike_buenosaires
# 2                              biketobike
# 3                                movo_bue
# ...

# %%
# EXAMPLE:
# capomulin_df = clean_data_df[clean_data_df["Drug Regimen"] == "Capomulin"]

us_systems = system_data[system_data['Country Code'] == 'US']
us_systems
# Out:
#     Country Code                Name                    Location  \
# 339           US         Asbury Park             Asbury Park, NJ
# 340           US              Austin                  Austin, TX
# 341           US      Austin B-cycle                  Austin, TX
# 342           US     Aventura BCycle                Aventura, FL
# 343           US          Bay Wheels  San Francisco Bay Area, CA
# ..           ...                 ...                         ...
# 556           US      Wheels Orlando                 Orlando, FL
# 557           US    Wheels San Diego               San Diego, CA
# 558           US      Wheels Seattle                 Seattle, WA
# 559           US  Wheels Tallahassee             Tallahassee, FL
# 560           US        Wheels Tempe                   Tempe, AZ
#
#                                 System ID                          URL  \
# 339                      Link_Asbury_Park        https://www.link.city
# ...
